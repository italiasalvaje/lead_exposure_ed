# %%
# Add Pandas dependency

import pandas as pd

# %%
# Files to load
week1 = "WeeklyReports/1001_1008.csv"

# %%
# Read RHV addresses 

week1_df = pd.read_csv(week1)
week1_df
# Out:
#          Timestamp Promotor              Address   Contact  \
# 0    10/3/22 13:32    Maria  1617 Mt Oliveira Dr        No
# 1    10/3/22 13:33    Diego  1612 Mt Oliveira Dr        No
# 2    10/3/22 13:34   MIguel  1609 Mt Oliveira Dr  Yes / Si
# 3    10/3/22 13:34    Maria  1625 Mt Oliveira Dr  Yes / Si
# 4    10/3/22 13:35    Diego  1620 Mt Oliveira Dr        No
# ..             ...      ...                  ...       ...
# 201  10/3/22 17:31    Diego  2204 Vista Verde Dr        No
# 202  10/3/22 17:32   Miguel        3312 Sueno Dr  Yes / Si
# 203  10/3/22 17:32    Jacki  2202 Vista Verde Dr        No
# 204  10/3/22 17:34    Maria        3319 Sueno Dr        No
# 205  10/3/22 17:34   Miguel     3329 Floresta Dr  Yes / Si
#
#                                       Language  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2                             English / Ingles
# 3                            Spanish / Espanol
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 201  Did not take survey / No tomo la encuesta
# 202                           English / Ingles
# 203  Did not take survey / No tomo la encuesta
# 204  Did not take survey / No tomo la encuesta
# 205                           English / Ingles
#
#                                          Study  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2    Did not take survey / No tomo la encuesta
# 3    Did not take survey / No tomo la encuesta
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 201  Did not take survey / No tomo la encuesta
# 202  Did not take survey / No tomo la encuesta
# 203  Did not take survey / No tomo la encuesta
# 204  Did not take survey / No tomo la encuesta
# 205  Did not take survey / No tomo la encuesta
#
#                                         Tested PrimaryCare  \
# 0    Did not take survey / No tomo la encuesta         NaN
# 1    Did not take survey / No tomo la encuesta         NaN
# 2    Did not take survey / No tomo la encuesta         NaN
# 3    Did not take survey / No tomo la encuesta         NaN
# 4    Did not take survey / No tomo la encuesta         NaN
# ..                                         ...         ...
# 201  Did not take survey / No tomo la encuesta         NaN
# 202  Did not take survey / No tomo la encuesta         NaN
# 203  Did not take survey / No tomo la encuesta         NaN
# 204  Did not take survey / No tomo la encuesta         NaN
# 205  Did not take survey / No tomo la encuesta         NaN
#
#      PrimaryCareResources                                Precautions  \
# 0                     NaN  Did not take survey / No tomo la encuesta
# 1                     NaN  Did not take survey / No tomo la encuesta
# 2                     NaN  Did not take survey / No tomo la encuesta
# 3                     NaN  Did not take survey / No tomo la encuesta
# 4                     NaN  Did not take survey / No tomo la encuesta
# ..                    ...                                        ...
# 201                   NaN  Did not take survey / No tomo la encuesta
# 202                   NaN  Did not take survey / No tomo la encuesta
# 203                   NaN  Did not take survey / No tomo la encuesta
# 204                   NaN  Did not take survey / No tomo la encuesta
# 205                   NaN  Did not take survey / No tomo la encuesta
#
#                                       Meetings  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2    Did not take survey / No tomo la encuesta
# 3    Did not take survey / No tomo la encuesta
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 201  Did not take survey / No tomo la encuesta
# 202  Did not take survey / No tomo la encuesta
# 203  Did not take survey / No tomo la encuesta
# 204  Did not take survey / No tomo la encuesta
# 205  Did not take survey / No tomo la encuesta
#
#                                       Revision  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2    Did not take survey / No tomo la encuesta
# 3    Did not take survey / No tomo la encuesta
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 201  Did not take survey / No tomo la encuesta
# 202  Did not take survey / No tomo la encuesta
# 203  Did not take survey / No tomo la encuesta
# 204  Did not take survey / No tomo la encuesta
# 205  Did not take survey / No tomo la encuesta
#
#                                        Effects Name Phone Email Questions  \
# 0    Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 1    Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 2    Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 3    Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 4    Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# ..                                         ...  ...   ...   ...       ...
# 201  Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 202  Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 203  Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 204  Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 205  Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
#
#                                          Fliers Assignment
# 0    Left at the address / Deje en la direccion          Q
# 1    Left at the address / Deje en la direccion          Q
# 2    Handed to resident / Entregue al residente          Q
# 3       Did not leave fliers / No deje folletos          Q
# 4    Left at the address / Deje en la direccion          Q
# ..                                          ...        ...
# 201  Left at the address / Deje en la direccion          R
# 202     Did not leave fliers / No deje folletos          R
# 203  Left at the address / Deje en la direccion          R
# 204  Left at the address / Deje en la direccion          R
# 205     Did not leave fliers / No deje folletos          R
#
# [206 rows x 19 columns]

# %%
#get number of responses to study question 
week1_count = week1_df.count()
week1_count
# Out:
# Timestamp               206
# Promotor                206
# Address                 206
# Contact                 206
# Language                206
# Study                   206
# Tested                  206
# PrimaryCare              31
# PrimaryCareResources      0
# Precautions             206
# Meetings                206
# Revision                206
# Effects                 206
# Name                      5
# Phone                     3
# Email                     1
# Questions                 5
# Fliers                  206
# Assignment              206
# dtype: int64

# %%
week1_df.isnull().sum()
# Out:
# Timestamp                42
# Promotor                 42
# Address                  42
# Contact                  42
# Language                 42
# Study                    42
# Tested                   42
# PrimaryCare             217
# PrimaryCareResources    248
# Precautions              42
# Meetings                 42
# Revision                 42
# Effects                  42
# Name                    243
# Phone                   245
# Email                   247
# Questions               243
# Fliers                   42
# Assignment               42
# dtype: int64

# %%
#fill empty rows with "Did not take survey / No tomo la encuesta"
week1_df[['Language','PrimaryCare','PrimaryCareResources','Meetings','Revision','Effects']]=week1_df[['Language','PrimaryCare','PrimaryCareResources','Meetings','Revision','Effects']].fillna('Did not take survey / No tomo la encuesta')


#view assignemnts
week1_df
# Out:
#          Timestamp Promotor              Address   Contact  \
# 0    10/3/22 13:32    Maria  1617 Mt Oliveira Dr        No
# 1    10/3/22 13:33    Diego  1612 Mt Oliveira Dr        No
# 2    10/3/22 13:34   MIguel  1609 Mt Oliveira Dr  Yes / Si
# 3    10/3/22 13:34    Maria  1625 Mt Oliveira Dr  Yes / Si
# 4    10/3/22 13:35    Diego  1620 Mt Oliveira Dr        No
# ..             ...      ...                  ...       ...
# 243            NaN      NaN                  NaN       NaN
# 244            NaN      NaN                  NaN       NaN
# 245            NaN      NaN                  NaN       NaN
# 246            NaN      NaN                  NaN       NaN
# 247            NaN      NaN                  NaN       NaN
#
#                                       Language  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2                             English / Ingles
# 3                            Spanish / Espanol
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 243  Did not take survey / No tomo la encuesta
# 244  Did not take survey / No tomo la encuesta
# 245  Did not take survey / No tomo la encuesta
# 246  Did not take survey / No tomo la encuesta
# 247  Did not take survey / No tomo la encuesta
#
#                                          Study  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2    Did not take survey / No tomo la encuesta
# 3    Did not take survey / No tomo la encuesta
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 243                                        NaN
# 244                                        NaN
# 245                                        NaN
# 246                                        NaN
# 247                                        NaN
#
#                                         Tested  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2    Did not take survey / No tomo la encuesta
# 3    Did not take survey / No tomo la encuesta
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 243                                        NaN
# 244                                        NaN
# 245                                        NaN
# 246                                        NaN
# 247                                        NaN
#
#                                    PrimaryCare  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2    Did not take survey / No tomo la encuesta
# 3    Did not take survey / No tomo la encuesta
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 243  Did not take survey / No tomo la encuesta
# 244  Did not take survey / No tomo la encuesta
# 245  Did not take survey / No tomo la encuesta
# 246  Did not take survey / No tomo la encuesta
# 247  Did not take survey / No tomo la encuesta
#
#                           PrimaryCareResources  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2    Did not take survey / No tomo la encuesta
# 3    Did not take survey / No tomo la encuesta
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 243  Did not take survey / No tomo la encuesta
# 244  Did not take survey / No tomo la encuesta
# 245  Did not take survey / No tomo la encuesta
# 246  Did not take survey / No tomo la encuesta
# 247  Did not take survey / No tomo la encuesta
#
#                                    Precautions  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2    Did not take survey / No tomo la encuesta
# 3    Did not take survey / No tomo la encuesta
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 243                                        NaN
# 244                                        NaN
# 245                                        NaN
# 246                                        NaN
# 247                                        NaN
#
#                                       Meetings  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2    Did not take survey / No tomo la encuesta
# 3    Did not take survey / No tomo la encuesta
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 243  Did not take survey / No tomo la encuesta
# 244  Did not take survey / No tomo la encuesta
# 245  Did not take survey / No tomo la encuesta
# 246  Did not take survey / No tomo la encuesta
# 247  Did not take survey / No tomo la encuesta
#
#                                       Revision  \
# 0    Did not take survey / No tomo la encuesta
# 1    Did not take survey / No tomo la encuesta
# 2    Did not take survey / No tomo la encuesta
# 3    Did not take survey / No tomo la encuesta
# 4    Did not take survey / No tomo la encuesta
# ..                                         ...
# 243  Did not take survey / No tomo la encuesta
# 244  Did not take survey / No tomo la encuesta
# 245  Did not take survey / No tomo la encuesta
# 246  Did not take survey / No tomo la encuesta
# 247  Did not take survey / No tomo la encuesta
#
#                                        Effects Name Phone Email Questions  \
# 0    Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 1    Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 2    Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 3    Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 4    Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# ..                                         ...  ...   ...   ...       ...
# 243  Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 244  Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 245  Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 246  Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
# 247  Did not take survey / No tomo la encuesta  NaN   NaN   NaN       NaN
#
#                                          Fliers Assignment
# 0    Left at the address / Deje en la direccion          Q
# 1    Left at the address / Deje en la direccion          Q
# 2    Handed to resident / Entregue al residente          Q
# 3       Did not leave fliers / No deje folletos          Q
# 4    Left at the address / Deje en la direccion          Q
# ..                                          ...        ...
# 243                                         NaN        NaN
# 244                                         NaN        NaN
# 245                                         NaN        NaN
# 246                                         NaN        NaN
# 247                                         NaN        NaN
#
# [248 rows x 19 columns]

# %%
week1_df.isnull().sum()
# Out:
# Timestamp                42
# Promotor                 42
# Address                  42
# Contact                  42
# Language                  0
# Study                    42
# Tested                   42
# PrimaryCare               0
# PrimaryCareResources      0
# Precautions              42
# Meetings                  0
# Revision                  0
# Effects                   0
# Name                    243
# Phone                   245
# Email                   247
# Questions               243
# Fliers                   42
# Assignment               42
# dtype: int64

# %%
week1_df.Promotor.unique()
# Out:
# array(['Maria', 'Diego', 'MIguel', 'Jacki', 'Miguel', nan], dtype=object)

# %%
week1_df.Contact.value_counts()
# Out:
# No          161
# Yes / Si     45
# Name: Contact, dtype: int64

# %%
week1_df.Language.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    206
# English / Ingles                              32
# Spanish / Espanol                              7
# Vietnamese                                     3
# Name: Language, dtype: int64

# %%
week1_df.Study.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    198
# Yes / Si                                       4
# No                                             4
# Name: Study, dtype: int64

# %%
week1_df.Tested.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    198
# Yes / Si                                       3
# Does not apply / No Aplica                     3
# No                                             1
# Maybe / Quizas                                 1
# Name: Tested, dtype: int64

# %%
week1_df.PrimaryCare.value_counts()
# Out:
# Did not take survey / No tomo la encuesta                                     217
# Does not have a primary care doctor / No tiene doctor de atencion primaria     28
# Yes / Si                                                                        2
# No                                                                              1
# Name: PrimaryCare, dtype: int64

# %%
week1_df.PrimaryCareResources.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    248
# Name: PrimaryCareResources, dtype: int64

# %%
week1_df.Precautions.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    198
# Yes / Si                                       7
# No                                             1
# Name: Precautions, dtype: int64

# %%
week1_df.Meetings.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    241
# No                                             6
# Yes / Si                                       1
# Name: Meetings, dtype: int64

# %%
week1_df.Revision.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    241
# No                                             5
# Yes / Si                                       2
# Name: Revision, dtype: int64

# %%
week1_df.Effects.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    241
# No                                             4
# Yes / Si                                       2
# Maybe / Quizas                                 1
# Name: Effects, dtype: int64

# %%
week1_df.notnull().sum()
# Out:
# Timestamp               206
# Promotor                206
# Address                 206
# Contact                 206
# Language                248
# Study                   206
# Tested                  206
# PrimaryCare             248
# PrimaryCareResources    248
# Precautions             206
# Meetings                248
# Revision                248
# Effects                 248
# Name                      5
# Phone                     3
# Email                     1
# Questions                 5
# Fliers                  206
# Assignment              206
# dtype: int64

# %%
week1_df.to_csv (r'WeeklyReports/926_930.csv', index = False, header=True)
