# %%
# Add Pandas dependency

import pandas as pd

# %%
# Files to load
week1 = "WeeklyReports/1016_1022.csv"

# %%
# Read RHV addresses 

week1_df = pd.read_csv(week1)
week1_df
# Out:
#            Timestamp   Promotor                  Address   Contact  \
# 0      10/17/22 8:52  Elizabeth        3311 San Rivas Dr        No
# 1      10/17/22 8:52       Ayde        3310 San Rivas Dr        No
# 2      10/17/22 8:54       Ayde        3316 San Rivas Dr        No
# 3      10/17/22 8:56       Ayde        3336 San Rivas Dr        No
# 4      10/17/22 8:56  Elizabeth        3319 San Rivas Dr  Yes / Si
# ...              ...        ...                      ...       ...
# 1080  10/21/22 17:28      Diego  2245 Lanai Ave Unit 149        No
# 1081  10/21/22 17:28     Miguel  2245 Lanai Ave Unit 147  Yes / Si
# 1082  10/21/22 17:29      Maria  2245 Lanai Ave Unit 157        No
# 1083  10/21/22 17:29     Miguel  2245 Lanai Ave Unit 145        No
# 1084  10/21/22 17:29      Diego  2245 Lanai Ave Unit 159        No
#
#                                        Language  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                              English / Ingles
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081                          Spanish / Espanol
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                           Study  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                                      Yes / Si
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081  Did not take survey / No tomo la encuesta
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                          Tested PrimaryCare  \
# 0     Did not take survey / No tomo la encuesta         NaN
# 1     Did not take survey / No tomo la encuesta         NaN
# 2     Did not take survey / No tomo la encuesta         NaN
# 3     Did not take survey / No tomo la encuesta         NaN
# 4                                      Yes / Si    Yes / Si
# ...                                         ...         ...
# 1080  Did not take survey / No tomo la encuesta         NaN
# 1081  Did not take survey / No tomo la encuesta         NaN
# 1082  Did not take survey / No tomo la encuesta         NaN
# 1083  Did not take survey / No tomo la encuesta         NaN
# 1084  Did not take survey / No tomo la encuesta         NaN
#
#                                    PrimaryCareResources  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     How to request lead testing from a primary car...
# ...                                                 ...
# 1080                                                NaN
# 1081                                                NaN
# 1082                                                NaN
# 1083                                                NaN
# 1084                                                NaN
#
#                                     Precautions  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                                      Yes / Si
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081  Did not take survey / No tomo la encuesta
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                        Meetings  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                                            No
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081  Did not take survey / No tomo la encuesta
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                        Revision  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                                            No
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081  Did not take survey / No tomo la encuesta
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                         Effects Name Phone Email  \
# 0     Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 1     Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 2     Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 3     Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 4                                      Yes / Si  NaN   NaN   NaN
# ...                                         ...  ...   ...   ...
# 1080  Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 1081  Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 1082  Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 1083  Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 1084  Did not take survey / No tomo la encuesta  NaN   NaN   NaN
#
#                                           Fliers Assignment
# 0     Left at the address / Deje en la direccion          S
# 1     Left at the address / Deje en la direccion          S
# 2     Left at the address / Deje en la direccion          S
# 3     Left at the address / Deje en la direccion          S
# 4     Handed to resident / Entregue al residente          S
# ...                                          ...        ...
# 1080  Left at the address / Deje en la direccion          F
# 1081  Handed to resident / Entregue al residente          F
# 1082  Left at the address / Deje en la direccion          F
# 1083     Did not leave fliers / No deje folletos          F
# 1084  Left at the address / Deje en la direccion          F
#
# [1085 rows x 18 columns]

# %%
#get number of responses to study question 
week1_count = week1_df.count()
week1_count
# Out:
# Timestamp               1085
# Promotor                1085
# Address                 1085
# Contact                 1085
# Language                1085
# Study                   1085
# Tested                  1085
# PrimaryCare               14
# PrimaryCareResources       7
# Precautions             1085
# Meetings                1085
# Revision                1085
# Effects                 1085
# Name                      40
# Phone                     31
# Email                      9
# Fliers                  1085
# Assignment              1085
# dtype: int64

# %%
week1_df.isnull().sum()
# Out:
# Timestamp                  0
# Promotor                   0
# Address                    0
# Contact                    0
# Language                   0
# Study                      0
# Tested                     0
# PrimaryCare             1071
# PrimaryCareResources    1078
# Precautions                0
# Meetings                   0
# Revision                   0
# Effects                    0
# Name                    1045
# Phone                   1054
# Email                   1076
# Fliers                     0
# Assignment                 0
# dtype: int64

# %%
#fill empty rows with "Did not take survey / No tomo la encuesta"
week1_df[['Language','PrimaryCare','PrimaryCareResources','Meetings','Revision','Effects']]=week1_df[['Language','PrimaryCare','PrimaryCareResources','Meetings','Revision','Effects']].fillna('Did not take survey / No tomo la encuesta')


#view assignemnts
week1_df
# Out:
#            Timestamp   Promotor                  Address   Contact  \
# 0      10/17/22 8:52  Elizabeth        3311 San Rivas Dr        No
# 1      10/17/22 8:52       Ayde        3310 San Rivas Dr        No
# 2      10/17/22 8:54       Ayde        3316 San Rivas Dr        No
# 3      10/17/22 8:56       Ayde        3336 San Rivas Dr        No
# 4      10/17/22 8:56  Elizabeth        3319 San Rivas Dr  Yes / Si
# ...              ...        ...                      ...       ...
# 1080  10/21/22 17:28      Diego  2245 Lanai Ave Unit 149        No
# 1081  10/21/22 17:28     Miguel  2245 Lanai Ave Unit 147  Yes / Si
# 1082  10/21/22 17:29      Maria  2245 Lanai Ave Unit 157        No
# 1083  10/21/22 17:29     Miguel  2245 Lanai Ave Unit 145        No
# 1084  10/21/22 17:29      Diego  2245 Lanai Ave Unit 159        No
#
#                                        Language  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                              English / Ingles
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081                          Spanish / Espanol
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                           Study  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                                      Yes / Si
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081  Did not take survey / No tomo la encuesta
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                          Tested  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                                      Yes / Si
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081  Did not take survey / No tomo la encuesta
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                     PrimaryCare  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                                      Yes / Si
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081  Did not take survey / No tomo la encuesta
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                    PrimaryCareResources  \
# 0             Did not take survey / No tomo la encuesta
# 1             Did not take survey / No tomo la encuesta
# 2             Did not take survey / No tomo la encuesta
# 3             Did not take survey / No tomo la encuesta
# 4     How to request lead testing from a primary car...
# ...                                                 ...
# 1080          Did not take survey / No tomo la encuesta
# 1081          Did not take survey / No tomo la encuesta
# 1082          Did not take survey / No tomo la encuesta
# 1083          Did not take survey / No tomo la encuesta
# 1084          Did not take survey / No tomo la encuesta
#
#                                     Precautions  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                                      Yes / Si
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081  Did not take survey / No tomo la encuesta
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                        Meetings  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                                            No
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081  Did not take survey / No tomo la encuesta
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                        Revision  \
# 0     Did not take survey / No tomo la encuesta
# 1     Did not take survey / No tomo la encuesta
# 2     Did not take survey / No tomo la encuesta
# 3     Did not take survey / No tomo la encuesta
# 4                                            No
# ...                                         ...
# 1080  Did not take survey / No tomo la encuesta
# 1081  Did not take survey / No tomo la encuesta
# 1082  Did not take survey / No tomo la encuesta
# 1083  Did not take survey / No tomo la encuesta
# 1084  Did not take survey / No tomo la encuesta
#
#                                         Effects Name Phone Email  \
# 0     Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 1     Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 2     Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 3     Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 4                                      Yes / Si  NaN   NaN   NaN
# ...                                         ...  ...   ...   ...
# 1080  Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 1081  Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 1082  Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 1083  Did not take survey / No tomo la encuesta  NaN   NaN   NaN
# 1084  Did not take survey / No tomo la encuesta  NaN   NaN   NaN
#
#                                           Fliers Assignment
# 0     Left at the address / Deje en la direccion          S
# 1     Left at the address / Deje en la direccion          S
# 2     Left at the address / Deje en la direccion          S
# 3     Left at the address / Deje en la direccion          S
# 4     Handed to resident / Entregue al residente          S
# ...                                          ...        ...
# 1080  Left at the address / Deje en la direccion          F
# 1081  Handed to resident / Entregue al residente          F
# 1082  Left at the address / Deje en la direccion          F
# 1083     Did not leave fliers / No deje folletos          F
# 1084  Left at the address / Deje en la direccion          F
#
# [1085 rows x 18 columns]

# %%
week1_df.isnull().sum()
# Out:
# Timestamp                  0
# Promotor                   0
# Address                    0
# Contact                    0
# Language                   0
# Study                      0
# Tested                     0
# PrimaryCare                0
# PrimaryCareResources       0
# Precautions                0
# Meetings                   0
# Revision                   0
# Effects                    0
# Name                    1045
# Phone                   1054
# Email                   1076
# Fliers                     0
# Assignment                 0
# dtype: int64

# %%
week1_df.Promotor.unique()
# Out:
# array(['Elizabeth', 'Ayde', 'Diego', 'Miguel', 'Maria'], dtype=object)

# %%
week1_df.Contact.value_counts()
# Out:
# No          854
# Yes / Si    231
# Name: Contact, dtype: int64

# %%
week1_df.Language.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    860
# English / Ingles                             144
# Spanish / Espanol                             70
# Vietnamese                                     8
# Chinese (Madarin/Cantonese)                    1
# Hindi                                          1
# Arabic                                         1
# Name: Language, dtype: int64

# %%
week1_df.Study.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    990
# Yes / Si                                      53
# No                                            41
# Maybe / Quizas                                 1
# Name: Study, dtype: int64

# %%
week1_df.Tested.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    992
# Yes / Si                                      36
# Does not apply / No Aplica                    34
# Maybe / Quizas                                12
# No                                            11
# Name: Tested, dtype: int64

# %%
week1_df.PrimaryCare.value_counts()
# Out:
# Did not take survey / No tomo la encuesta                                     1071
# Yes / Si                                                                         7
# Does not have a primary care doctor / No tiene doctor de atencion primaria       7
# Name: PrimaryCare, dtype: int64

# %%
week1_df.PrimaryCareResources.value_counts()
# Out:
# Did not take survey / No tomo la encuesta                                                                                                    1078
# How to request lead testing from a primary care doctor / Cómo solicitar una prueba de detección de plomo a un médico de atención primaria       7
# Name: PrimaryCareResources, dtype: int64

# %%
week1_df.Precautions.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    995
# Yes / Si                                      84
# No                                             4
# Maybe / Quizas                                 2
# Name: Precautions, dtype: int64

# %%
week1_df.Meetings.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    999
# No                                            58
# Yes / Si                                      20
# Maybe / Quizas                                 8
# Name: Meetings, dtype: int64

# %%
week1_df.Revision.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    999
# No                                            54
# Yes / Si                                      26
# Maybe / Quizas                                 6
# Name: Revision, dtype: int64

# %%
week1_df.Effects.value_counts()
# Out:
# Did not take survey / No tomo la encuesta    999
# No                                            43
# Yes / Si                                      38
# Maybe / Quizas                                 5
# Name: Effects, dtype: int64

# %%
week1_df.notnull().sum()
# Out:
# Timestamp               1085
# Promotor                1085
# Address                 1085
# Contact                 1085
# Language                1085
# Study                   1085
# Tested                  1085
# PrimaryCare             1085
# PrimaryCareResources    1085
# Precautions             1085
# Meetings                1085
# Revision                1085
# Effects                 1085
# Name                      40
# Phone                     31
# Email                      9
# Fliers                  1085
# Assignment              1085
# dtype: int64

# %%
week1_df.to_csv (r'WeeklyReports/1016_1022.csv', index = False, header=True)
