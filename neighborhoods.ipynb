# %%
# Add Pandas dependency

import pandas as pd

# %%
# Load file

neighborhoods = "Neighborhoods/neighborhoods.csv"

# %%
# Read Neighborhoods

neighborhoods_df = pd.read_csv(neighborhoods)
neighborhoods_df
# Out:
#       Answered  Attending  Knock  Notes              Name       Phone  \
# 0          NaN        NaN    NaN    NaN  Alejandro medoza   213290826
# 1          NaN        NaN    NaN    NaN     Ricardo Gomez   408334578
# 2          NaN        NaN    NaN    NaN      Nuria Garcia   408551848
# 3          NaN        NaN    NaN    NaN         Gieanjali  2087617750
# 4          NaN        NaN    NaN    NaN   Mila Villarreal  2092526032
# ...        ...        ...    ...    ...               ...         ...
# 1030       NaN        NaN    NaN    NaN
# 1031       NaN        NaN    NaN    NaN
# 1032       NaN        NaN    NaN    NaN
# 1033       NaN        NaN    NaN    NaN
# 1034       NaN        NaN    NaN    NaN
#
#                           Email             Address   Contact  \
# 0                                  10311 Lochner Dr  Yes / Si
# 1                                  3282 Mt Vista Dr  Yes / Si
# 2                                1721 S Capitol Ave  Yes / Si
# ...

# %%
neighborhoods_df.Phone.notnull().sum()
# Out:
# 1035

# %%
neighborhoods_df.Neighborhood.value_counts()
# Out:
# Tropicana Lanai             111
# Tanglewood El Monte          73
# Lanai Cunnigham              71
# Edge                         70
# Mt Pleasant South            69
# East Dobern                  61
# Tropicana                    49
# Tanglewood El Monte West     47
# Cassell West                 47
# Mt Pleasant North            45
# Overfelt                     44
# Kollmar                      42
# Capitola Goss                39
# Hillview North               34
# Meadows                      34
# Cinderella                   25
# Edge South                   23
# Cassell East                 23
# Dorsa Miller                 21
# Holly Oak                    20
# Coldwater                    18
# Mt Pleasant                  18
# Hidden Glen North            17
# Hidden Glen Northeast        15
# Arbuckle                     14
# Yum Yum Tract                 5
# Name: Neighborhood, dtype: int64

# %%
Cassell_East = neighborhoods_df[(neighborhoods_df["Neighborhood"] == "Cassell East")]
Cassell_East
# Out:
#       Answered  Attending  Knock  Notes              Name       Phone  \
# 25         NaN        NaN    NaN    NaN            Lin To  4082367209
# 40         NaN        NaN    NaN    NaN    Isidra Berrios  4082725778
# 93         NaN        NaN    NaN    NaN  Effiong phillips  4084492597
# 104        NaN        NaN    NaN    NaN               Sam  4085079928
# 152        NaN        NaN    NaN    NaN     Maniel portla  4086408545
# 192        NaN        NaN    NaN    NaN             Tracy  4087247875
# 224        NaN        NaN    NaN    NaN      Pamela Akina  4088137111
# 249        NaN        NaN    NaN    NaN   Mirna Rodriguez  4088543270
# 343        NaN        NaN    NaN    NaN             Maria  6692900724
# 351        NaN        NaN    NaN    NaN          Santiago  6693481511
# 995        NaN        NaN    NaN    NaN
# 996        NaN        NaN    NaN    NaN          Jaymesha
# 997        NaN        NaN    NaN    NaN
# 998        NaN        NaN    NaN    NaN
# ...

# %%
Cassell_East.to_csv (r'Neighborhoods/CassellEast.csv', index = False, header=True)

# %%
Hillview_North = neighborhoods_df[(neighborhoods_df["Neighborhood"] == "Hillview North")]
Hillview_North
# Out:
#      Answered  Attending  Knock  Notes                Name       Phone  \
# 8         NaN        NaN    NaN    NaN       Jorge Naranjo  3232436669
# 13        NaN        NaN    NaN    NaN        Jose Mendoza  4082072983
# 38        NaN        NaN    NaN    NaN          A nakayama  4082587891
# 69        NaN        NaN    NaN    NaN       Juan Cacillas  4083980107
# 100       NaN        NaN    NaN    NaN  Cristina Hernandez  4084695021
# 174       NaN        NaN    NaN    NaN      Consuelo Serna  4086776965
# 180       NaN        NaN    NaN    NaN        Maria santan  4086918627
# 188       NaN        NaN    NaN    NaN       Maria benitez  4087149957
# 215       NaN        NaN    NaN    NaN      Veronica licon  4087849040
# 217       NaN        NaN    NaN    NaN         Blanca soto  4087868235
# 219       NaN        NaN    NaN    NaN     Verta Jimemenez  4087914726
# 230       NaN        NaN    NaN    NaN          Long huynh  4088285799
# ...

# %%
Hillview_North.to_csv (r'Neighborhoods/HillviewNorth.csv', index = False, header=True)
